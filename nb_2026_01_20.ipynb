# %% [markdown]
# <a href="https://colab.research.google.com/github/echiino/scratchpad/blob/main/nb_2026_01_20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! git clone https://github.com/echiino/scratchpad
# %run ./scratchpad/get_data.py
# Out:
# Cloning into 'scratchpad'...
# remote: Enumerating objects: 30, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 30 (delta 4), reused 1 (delta 1), pack-reused 24 (from 1)
# Receiving objects: 100% (30/30), 28.96 KiB | 706.00 KiB/s, done.
# Resolving deltas: 100% (9/9), done.
# ...
# Download complete
# Extracting data files...
# Data extracted

# %%
import urllib.request
import os
import zipfile
import os

def download_data(force=False):
    """Download and extract course data from Zenodo."""

    zip_path = 'data.zip'
    data_dir = './data'

    if not os.path.exists(zip_path) or force:
        print("Downloading course data...")
        urllib.request.urlretrieve(
            'https://zenodo.org/records/18235955/files/data.zip?download=1',
            zip_path
        )
        print("Download complete")

    if not os.path.exists(data_dir) or force:
        print("Extracting data files...")
        with zipfile.ZipFile(zip_path, 'r') as zip_ref:
            zip_ref.extractall(data_dir)
        print("Data extracted")

    return data_dir


if __name__ == "__main__":
    download_data()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('/content/data/crimebystatecombinedwithunemployment.csv',
                 encoding = 'latin1')
df.head()
# Out:
#   state  unemployment  year  Population  violent total  Murder  rape  Robbery  \
# 0    AL         6.808  1976     3665000          388.8    15.1  21.7     96.0
# 1    AL         7.325  1977     3690000          414.4    14.2  25.2     96.8
# 2    AL         6.380  1978     3742000          419.1    13.3  25.5     99.1
# 3    AL         7.158  1979     3769000          413.3    13.2  27.5    109.5
# 4    AL         8.867  1980     3861466          448.5    13.2  30.0    132.1
#
#    Aggravated assault  property total  Burglary  Larceny theft  vehicle theft
# 0               256.0          3419.5    1170.0         1987.2          262.3
# 1               278.3          3298.2    1135.5         1881.9          280.7
# 2               281.2          3519.7    1229.3         1987.9          302.5
# 3               263.1          3830.5    1287.3         2223.2          320.1
# 4               273.2          4485.1    1526.7         2642.2          316.2

# %%
print("\n head:")
print(df.head())

print("\n tail:")
print(df.tail())

print("\n types:")
print(df.dtypes)

print("\n shape:")
print(df.shape)

print("\n columns:")
print(df.columns)
# Out:
#  head:
#   state  unemployment  year  Population  violent total  Murder  rape  Robbery  \
# 0    AL         6.808  1976     3665000          388.8    15.1  21.7     96.0
# 1    AL         7.325  1977     3690000          414.4    14.2  25.2     96.8
# 2    AL         6.380  1978     3742000          419.1    13.3  25.5     99.1
# 3    AL         7.158  1979     3769000          413.3    13.2  27.5    109.5
# 4    AL         8.867  1980     3861466          448.5    13.2  30.0    132.1
#
#    Aggravated assault  property total  Burglary  Larceny theft  vehicle theft
# 0               256.0          3419.5    1170.0         1987.2          262.3
# 1               278.3          3298.2    1135.5         1881.9          280.7
# 2               281.2          3519.7    1229.3         1987.9          302.5
# 3               263.1          3830.5    1287.3         2223.2          320.1
# 4               273.2          4485.1    1526.7         2642.2          316.2
#
#  tail:
# ...

# %%
df['Murder'].describe()
# Out:
# count    1989.000000
# mean        6.651785
# std         6.560408
# min         0.200000
# 25%         3.200000
# 50%         5.400000
# 75%         8.400000
# max        80.600000
# Name: Murder, dtype: float64
